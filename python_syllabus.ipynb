# %% [markdown]
# # 🐍 Core Python Topics (Complete Syllabus)
#
# ## 1. Python Basics
# - Introduction to Python
# - Installation & Environment Setup
# - Running Python (Interpreter, Script Mode)
# - Comments, Keywords
# - Variables & Naming Conventions
# - Basic Input/Output
# - Python Memory Model (overview)
#
# ---
#
# ## 2. Data Types
# - Numbers (int, float, complex)
# - Strings
# - Lists
# - Tuples
# - Dictionaries
# - Sets
# - Booleans
# - Typecasting
#
# ---
#
# ## 3. Operators
# - Arithmetic Operators
# - Comparison Operators
# - Logical Operators
# - Assignment Operators
# - Bitwise Operators
# - Identity Operators (`is`)
# - Membership Operators (`in`)
#
# ---
#
# ## 4. Control Flow
# - `if`, `elif`, `else`
# - `for` loop
# - `while` loop
# - Loop Control Statements: `break`, `continue`, `pass`
# - Nested Loops & Conditions
#
# ---
#
# ## 5. Functions
# - Defining and Calling Functions
# - Function Arguments:
#   - Required
#   - Default
#   - Keyword
#   - Variable-length (`*args`, `**kwargs`)
# - Return Statements
# - Lambda Functions
# - `map`, `filter`, `reduce`
# - Recursion
#
# ---
#
# ## 6. Data Structures (Advanced Operations)
# - List/Dict/Set/Tuple Methods
# - List Comprehension
# - Dictionary & Set Comprehension
# - `zip()`
# - `enumerate()`
# - Shallow vs Deep Copy
# - Mutable vs Immutable Types
#
# ---
#
# ## 7. File Handling
# - Opening and Closing Files
# - Read / Write / Append
# - File Modes
# - Working with Text & CSV Files
# - Using `with` (Context Manager)
#
# ---
#
# ## 8. Error & Exception Handling
# - `try`
# - `except`
# - `else`
# - `finally`
# - Raising Exceptions
# - Custom Exceptions
#
# ---
#
# ## 9. Modules & Packages
# - Importing Modules
# - Built-in Modules (`math`, `random`, `os`, `sys`, `datetime`)
# - Creating User-Defined Modules
# - Creating & Using Packages
# - Virtual Environments (`venv`)
#
# ---
#
# ## 10. Object-Oriented Programming (OOP)
# - Classes & Objects
# - `__init__` Constructor
# - Instance & Class Variables
# - Methods
# - Encapsulation
# - Inheritance
# - Polymorphism
# - Abstraction
# - `super()` Keyword
# - Magic/Dunder Methods
# - Class Methods & Static Methods
#
# ---
#
# ## 11. Iterators & Generators
# - `__iter__`, `__next__`
# - Custom Iterators
# - `yield` Keyword
# - Generator Functions
# - Generator Expressions
#
# ---
#
# ## 12. Advanced Python Concepts (Recommended)
# - Decorators
# - Context Managers
# - `typing` Module (Type Hints)
# - Regular Expressions (`re` module)
# - `collections` Module (Counter, defaultdict, OrderedDict)
#
# ---
#
# ## 13. Python Standard Libraries
# - `os`, `sys`, `pathlib`
# - `datetime`
# - `json`
# - `logging`
#
# ---
#
# ## Optional (Useful for Data Science)
# - Basic `pip` usage
# - Virtual Environment workflow
