# %% [markdown]
# # 🐍 Top Python Interview Questions
#
# ## ✅ Basic Python Questions
# 1. What is Python? What are its key features?
# 2. What is PEP 8 and why is it important?
# 3. What is the difference between a list and a tuple?
# 4. What is mutable vs immutable?
# 5. What are local and global variables?
# 6. What is the use of `pass`?
# 7. What is `__init__`?
# 8. Difference between `==` and `is`.
# 9. What are modules and packages?
# 10. What is a virtual environment?
#
# ---
#
# ## ✅ Data Types & Collections
# 11. What is a dictionary? Why is it fast?
# 12. What is list comprehension?
# 13. What is slicing?
# 14. How do you remove duplicates from a list?
# 15. Difference between `append()` and `extend()`.
#
# ---
#
# ## ✅ Functions & OOP
# 16. What are *args and **kwargs?
# 17. What is recursion?
# 18. Function vs Method.
# 19. Explain OOP concepts:
#     - Inheritance
#     - Encapsulation
#     - Polymorphism
#     - Abstraction
# 20. What is method overriding?
#
# ---
#
# ## ✅ Important Python Concepts
# 21. What is a lambda function?
# 22. What are decorators?
# 23. What is a generator?
# 24. What is an iterator?
# 25. Shallow copy vs Deep copy.
#
# ---
#
# ## ✅ Error Handling
# 26. What is exception handling?
# 27. Difference between `raise` and `assert`.
# 28. What is the use of `finally`?
#
# ---
#
# ## ✅ Python Memory & Performance
# 29. How does Python manage memory?
# 30. What is GIL (Global Interpreter Lock)?
# 31. What is garbage collection?
#
# ---
#
# ## ✅ File Handling
# 32. How do you read and write files?
# 33. Difference between `read()`, `readline()`, and `readlines()`.
#
# ---
#
# ## ✅ Python for Data Analysis
# 34. How do you handle missing values in Python?
# 35. What are NumPy arrays?
# 36. What is vectorization in NumPy?
# 37. How to merge/join dataframes in Pandas?
# 38. How to handle duplicates in Pandas?
# 39. What is GroupBy?
# 40. What is broadcasting?
#
# ---
#
# ## ✅ Python + SQL
# 41. How do you connect Python with SQL?
# 42. What is a cursor in Python SQL operations?
#
# ---
#
# ## ✅ Coding / Logical Questions
# 43. Reverse a string in Python.
# 44. Find second largest number in a list.
# 45. Count frequency of characters in a string.
# 46. Check if a number is prime.
# 47. Check if a string is palindrome.
# 48. Generate Fibonacci series.
# 49. Remove duplicates without using set.
# 50. Flatten a nested list.
